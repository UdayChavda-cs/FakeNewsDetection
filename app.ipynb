# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import classification_report
import re
import joblib
import string

# %%
fake = pd.read_csv("Fake.csv")
true = pd.read_csv("True.csv")

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
fake["class"] = 0
true["class"] = 1

# %%
data = pd.concat([fake, true], axis=0)

# %%
data.sample(10)
# Out:
#                                                    title  \
# 3388    Stephen King BLASTS Republicans Cozying Up To...
# 7693    Trump Bails On CPAC And Republicans Are Now B...
# 19310  MEDIA ATTACKS TAYLOR SWIFT Over Refusal To Cri...
# 6398    Here’s Why Conservatives Are Silent About 201...
# 3112   Exclusive: Trump administration eyes hardening...
# 15326  EU states see Britain failing to meet Brexit d...
# 2825   Senior U.S., Russian diplomats to meet in Wash...
# 16178  SENIOR CIA INTEL: “Wiretapping of Trump Transi...
# 3320   Comey account could fuel obstruction accusatio...
# 8289   Organizers name TV journalists to moderate U.S...
#
#                                                     text          subject  \
# 3388   Vladimir Putin s name used to be mud with the ...             News
# 7693   It looks as though the man most likely to get ...             News
# 19310  Tom Barnes mocks Taylor Swift in his latest ar...        left-news
# 6398   Police in this country had a great run. Let s ...             News
# 3112   WASHINGTON (Reuters) - President Donald Trump’...     politicsNews
# 15326  BRUSSELS (Reuters) - EU envoys discussed on We...        worldnews
# 2825   WASHINGTON (Reuters) - U.S. Undersecretary of ...     politicsNews
# 16178                                                     Government News
# 3320   NEW YORK (Reuters) - Former FBI Director James...     politicsNews
# 8289   WASHINGTON (Reuters) - Journalists from NBC, A...     politicsNews
#
#                      date  class
# 3388    December 16, 2016      0
# 7693        March 4, 2016      0
# 19310        Jan 14, 2017      0
# 6398         May 13, 2016      0
# 3112       June 20, 2017       1
# 15326   November 8, 2017       1
# 2825       July 11, 2017       1
# 16178        Mar 27, 2017      0
# 3320        June 8, 2017       1
# 8289   September 2, 2016       1

# %%
data = data.drop(["title", "subject", "date"], axis=1)

# %%
data.reset_index(inplace=True)

# %%
data.drop(['index'],axis = 1,inplace=True)

# %%
data.sample(5)
# Out:
#                                                     text  class
# 15602  No need to file rules don t apply to Obama s a...      0
# 2281   It can easily be said that Donald Trump doesn ...      0
# 31340  SAN FRANCISCO (Reuters) - Facebook Inc (FB.O) ...      1
# 29316  TOKYO (Reuters) - Japan is hammering out plans...      1
# 26635  WASHINGTON (Reuters) - U.S. President Donald T...      1

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub('\[.*?\]',"",text)
    text = re.sub(r'\s+', ' ', text)
    return text.strip()
